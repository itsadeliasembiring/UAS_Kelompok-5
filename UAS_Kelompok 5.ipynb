# %%
# 1. Import Library dan Input Dataset
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, manhattan_distances
import matplotlib.pyplot as plt
import seaborn as sns
import random

# Load Dataset
books = pd.read_csv('Books.csv')
ratings = pd.read_csv('Books-Ratings.csv')
users = pd.read_csv('Users.csv')

# Menampilkan dataset
print("="*60)
print("1. DATASET")
print("="*60)

print("Dataset Books:")
display(books.head())
print(f"\nInfo Dataset Books: {books.shape[0]} rows, {books.shape[1]} columns")
print(books.info())

print("\nDataset Ratings:")
display(ratings.head())
print(f"\nInfo Dataset Ratings: {ratings.shape[0]} rows, {ratings.shape[1]} columns")
print(ratings.info())

print("\nDataset Users:")
display(users.head())
print(f"\nInfo Dataset Users: {users.shape[0]} rows, {users.shape[1]} columns")
print(users.info())

# 2. PreProcessing Data
print("\n" + "="*60)
print("2. PREPROCESSING DATA")
print("="*60)

# Gabung dataset terlebih dahulu
df = pd.merge(books, ratings, on='ISBN')
df = pd.merge(df, users, on='User-ID')
print(f"\nData setelah digabung: {df.shape[0]} rows, {df.shape[1]} columns")

# 2.1 CEK MISSING VALUE DAN HAPUS MISSING VALUE
print("\n" + "-"*50)
print("2.1 CEK MISSING VALUE DAN HAPUS MISSING VALUE")
print("-"*50)

print("\nMissing values sebelum preprocessing:")
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df) * 100).round(2)
missing_df = pd.DataFrame({
    'Missing Count': missing_values,
    'Percentage (%)': missing_percentage
})
print(missing_df[missing_df['Missing Count'] > 0])

# Handle Age dengan mean imputation
print(f"\nMengisi missing value Age dengan rata-rata: {df['Age'].mean():.2f}")
df['Age'] = df['Age'].fillna(df['Age'].mean())

# Hapus baris dengan missing value pada kolom penting lainnya
print("Menghapus baris dengan missing value pada kolom lainnya...")
df_before = df.shape[0]
df = df.dropna().reset_index(drop=True)
df_after = df.shape[0]
print(f"Data berkurang dari {df_before} menjadi {df_after} rows ({df_before - df_after} rows dihapus)")

print("\nMissing values setelah preprocessing:")
print(df.isnull().sum().sum(), "missing values tersisa")

# 2.2 CEK OUTLIER DAN HAPUS OUTLIER
print("\n" + "-"*50)
print("2.2 CEK OUTLIER DAN HAPUS OUTLIER")
print("-"*50)

# Cek outlier untuk Age
print("\nAnalisis outlier untuk kolom Age:")
Q1_age = df['Age'].quantile(0.25)
Q3_age = df['Age'].quantile(0.75)
IQR_age = Q3_age - Q1_age
lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age

outliers_age = df[(df['Age'] < lower_bound_age) | (df['Age'] > upper_bound_age)]
print(f"Q1: {Q1_age}, Q3: {Q3_age}, IQR: {IQR_age}")
print(f"Batas bawah: {lower_bound_age:.2f}, Batas atas: {upper_bound_age:.2f}")
print(f"Jumlah outlier Age: {len(outliers_age)} ({len(outliers_age)/len(df)*100:.2f}%)")

# Cek outlier untuk Book-Rating
print("\nAnalisis outlier untuk kolom Book-Rating:")
rating_stats = df['Book-Rating'].describe()
print(rating_stats)
print(f"Range valid rating: {df['Book-Rating'].min()} - {df['Book-Rating'].max()}")

# Hapus outlier Age (jika diperlukan - dalam kasus ini kita batasi umur 5-100 tahun)
print(f"\nMenghapus outlier Age (< 5 atau > 100 tahun)...")
df_before_outlier = df.shape[0]
df = df[(df['Age'] >= 5) & (df['Age'] <= 100)]
df_after_outlier = df.shape[0]
print(f"Data berkurang dari {df_before_outlier} menjadi {df_after_outlier} rows ({df_before_outlier - df_after_outlier} rows dihapus)")

# Hapus rating yang tidak valid (rating harus 0-10)
print(f"\nMenghapus rating tidak valid (di luar range 0-10)...")
df_before_rating = df.shape[0]
df = df[(df['Book-Rating'] >= 0) & (df['Book-Rating'] <= 10)]
df_after_rating = df.shape[0]
print(f"Data berkurang dari {df_before_rating} menjadi {df_after_rating} rows ({df_before_rating - df_after_rating} rows dihapus)")

# 2.3 NORMALISASI
print("\n" + "-"*50)
print("2.3 NORMALISASI")
print("-"*50)

# Encode User-ID dan ISBN
print("Melakukan encoding untuk User-ID dan ISBN...")
user_ids = df['User-ID'].unique()
isbn_list = df['ISBN'].unique()
user_to_idx = {user: idx for idx, user in enumerate(user_ids)}
isbn_to_idx = {isbn: idx for idx, isbn in enumerate(isbn_list)}
df['user_idx'] = df['User-ID'].map(user_to_idx)
df['isbn_idx'] = df['ISBN'].map(isbn_to_idx)
print(f"Total unique users: {len(user_ids)}")
print(f"Total unique books: {len(isbn_list)}")

# Normalisasi rating menggunakan MinMaxScaler
print("\nNormalisasi Book-Rating menggunakan MinMaxScaler...")
print(f"Rating sebelum normalisasi - Min: {df['Book-Rating'].min()}, Max: {df['Book-Rating'].max()}")
scaler = MinMaxScaler()
df['Book-Rating'] = scaler.fit_transform(df[['Book-Rating']])
print(f"Rating setelah normalisasi - Min: {df['Book-Rating'].min():.3f}, Max: {df['Book-Rating'].max():.3f}")

# Normalisasi Age (opsional)
print("\nNormalisasi Age menggunakan MinMaxScaler...")
print(f"Age sebelum normalisasi - Min: {df['Age'].min():.2f}, Max: {df['Age'].max():.2f}")
age_scaler = MinMaxScaler()
df['Age_normalized'] = age_scaler.fit_transform(df[['Age']])
print(f"Age setelah normalisasi - Min: {df['Age_normalized'].min():.3f}, Max: {df['Age_normalized'].max():.3f}")

print("\n" + "-"*50)
print("RINGKASAN PREPROCESSING")
print("-"*50)
print(f"Dataset final: {df.shape[0]} rows, {df.shape[1]} columns")
print(f"Unique users: {df['User-ID'].nunique()}")
print(f"Unique books: {df['ISBN'].nunique()}")
print(f"Rating range: {df['Book-Rating'].min():.3f} - {df['Book-Rating'].max():.3f}")
print(f"Age range: {df['Age'].min():.2f} - {df['Age'].max():.2f} tahun")
print("Missing values:", df.isnull().sum().sum())

print("\nSample data setelah preprocessing:")
display(df[['User-ID', 'ISBN', 'Book-Title', 'Book-Author', 'Book-Rating', 'Age', 'user_idx', 'isbn_idx']].head())

# 3. Similarity Calculation
print("\n" + "="*60)
print("3. SIMILARITY CALCULATION")
print("="*60)

# Buat matriks rating sparse
sparse_matrix = csr_matrix((df['Book-Rating'], (df['user_idx'], df['isbn_idx'])))
print(f"Ukuran matriks sparse: {sparse_matrix.shape} (users x books)")
print(f"Sparsity: {(1 - sparse_matrix.nnz / (sparse_matrix.shape[0] * sparse_matrix.shape[1])) * 100:.2f}%")

# Ambil hanya buku dengan minimal 10 rating untuk mengurangi noise
print("\nMemfilter buku dengan minimal 10 rating...")
popular_books = df.groupby('ISBN').filter(lambda x: len(x) >= 10)
popular_isbns = popular_books['ISBN'].unique()
popular_isbn_idx = [isbn_to_idx[isbn] for isbn in popular_isbns]
sparse_popular = sparse_matrix[:, popular_isbn_idx]
print(f"Buku populer: {len(popular_isbns)} dari {len(isbn_list)} total buku")
print(f"Ukuran matriks setelah filtering: {sparse_popular.shape}")

# a. Cosine Similarity
print("\nMenghitung Cosine Similarity...")
cos_sim = cosine_similarity(sparse_popular.T)
cos_sim_df = pd.DataFrame(cos_sim, index=popular_isbns, columns=popular_isbns)
print(f"Cosine similarity matrix shape: {cos_sim_df.shape}")

# b. Euclidean Distance (dijadikan similarity: sim = 1 / (1 + distance))
print("\nMenghitung Euclidean Similarity...")
euc_dist = euclidean_distances(sparse_popular.T)
euc_sim = 1 / (1 + euc_dist)
euc_sim_df = pd.DataFrame(euc_sim, index=popular_isbns, columns=popular_isbns)
print(f"Euclidean similarity matrix shape: {euc_sim_df.shape}")

# c. Manhattan Distance (L1 norm) - dijadikan similarity: sim = 1 / (1 + distance)
print("\nMenghitung Manhattan Similarity...")
manhattan_dist = manhattan_distances(sparse_popular.T)
manhattan_sim = 1 / (1 + manhattan_dist)
manhattan_sim_df = pd.DataFrame(manhattan_sim, index=popular_isbns, columns=popular_isbns)
print(f"Manhattan similarity matrix shape: {manhattan_sim_df.shape}")

print("\nContoh Similarity Values (5x5 sample):")
print("\nCosine Similarity:")
print(cos_sim_df.iloc[:5, :5].round(4))
print("\nEuclidean Similarity:")
print(euc_sim_df.iloc[:5, :5].round(4))
print("\nManhattan Similarity:")
print(manhattan_sim_df.iloc[:5, :5].round(4))

# 4. Collaborative Filtering: Item-Based
def get_recommendations(isbn, similarity_df, n=5):
    """Mendapatkan rekomendasi buku berdasarkan similarity matrix"""
    if isbn not in similarity_df.index:
        return []
    sim_scores = similarity_df[isbn].sort_values(ascending=False)[1:n+1]
    return sim_scores.index.tolist()

# 5. Evaluasi: 20 User dan rekomendasi untuk ketiga metrik similarity
print("\n" + "="*60)
print("4. EVALUASI SISTEM REKOMENDASI")
print("="*60)

random.seed(42)  # Untuk reproducibility
random_users = random.sample(list(df['User-ID'].unique()), 20)
print(f"Mengevaluasi sistem untuk {len(random_users)} user random...")

# Mapping ISBN ke Book-Title
isbn_to_title = pd.Series(books['Book-Title'].values, index=books['ISBN']).to_dict()

# Dictionary untuk menyimpan hasil evaluasi setiap metrik
evaluation_results = {
    'Cosine Similarity': {'success_count': 0, 'similarity_df': cos_sim_df, 'total_recommendations': 0},
    'Euclidean Similarity': {'success_count': 0, 'similarity_df': euc_sim_df, 'total_recommendations': 0},
    'Manhattan Similarity': {'success_count': 0, 'similarity_df': manhattan_sim_df, 'total_recommendations': 0}
}

for i, user in enumerate(random_users, 1):
    user_data = df[df['User-ID'] == user]
    if len(user_data) == 0:
        continue

    user_books = user_data['ISBN'].tolist()

    print(f"\n{'='*80}")
    print(f"EVALUASI USER {i}/20 - User-ID: {user}")
    print(f"{'='*80}")
    print(f"Buku yang pernah dibaca: {len(user_books)} buku")

    # Tampilkan semua buku yang pernah dibaca
    for j, isbn in enumerate(user_books):
        title = isbn_to_title.get(isbn, 'Judul tidak ditemukan')
        print(f"  {j+1}. {title[:50]}..." if len(title) > 50 else f"  {j+1}. {title}")

    # Evaluasi untuk setiap metrik similarity
    for method_name, method_data in evaluation_results.items():
        similarity_df = method_data['similarity_df']
        recommended_books = []

        # Generate rekomendasi berdasarkan similarity matrix
        for book in user_books:
            if book in similarity_df.index:
                recs = get_recommendations(book, similarity_df, n=3)
                recommended_books.extend(recs)

        # Hapus duplikat dan buku yang sudah dibaca
        recommended_books = list(set(recommended_books))
        recommended_books = [book for book in recommended_books if book not in user_books]

        method_data['total_recommendations'] += len(recommended_books)

        # Untuk evaluasi sederhana, kita anggap sukses jika ada rekomendasi yang dihasilkan
        success = len(recommended_books) > 0
        if success:
            method_data['success_count'] += 1

        # Tampilkan hasil per metrik
        print(f"\n--- {method_name} ---")
        if recommended_books:
            print(f"Rekomendasi: {len(recommended_books)} buku")
            # Tampilkan SEMUA rekomendasi
            for j, isbn in enumerate(recommended_books):
                title = isbn_to_title.get(isbn, 'Judul tidak ditemukan')
                print(f"  {j+1}. {title[:50]}..." if len(title) > 50 else f"  {j+1}. {title}")
        else:
            print("Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)")
        print(f"Jumlah rekomendasi: {len(recommended_books)} buku")

# Tampilkan ringkasan evaluasi akhir
print(f"\n{'='*80}")
print("RINGKASAN EVALUASI AKHIR")
print(f"{'='*80}")

results_summary = []
for method_name, method_data in evaluation_results.items():
    success_count = method_data['success_count']
    total_recs = method_data['total_recommendations']
    success_rate = (success_count / 20) * 100
    avg_recs = total_recs / 20

    results_summary.append({
        'Method': method_name,
        'Success Rate': f"{success_count}/20 ({success_rate:.1f}%)",
        'Avg Recommendations': f"{avg_recs:.1f} buku/user"
    })

    print(f"{method_name:20} : {success_count}/20 user ({success_rate:.1f}%) berhasil mendapat rekomendasi")
    print(f"{'':20}   Rata-rata {avg_recs:.1f} rekomendasi per user")

# Menentukan metrik terbaik
best_method = max(evaluation_results.keys(), key=lambda x: evaluation_results[x]['success_count'])
best_score = evaluation_results[best_method]['success_count']
print(f"\n🏆 Metrik terbaik: {best_method}")
print(f"   Berhasil memberikan rekomendasi untuk {best_score}/20 user")

# Tampilkan tabel ringkasan
print(f"\n{'='*80}")
print("TABEL PERBANDINGAN METRIK")
print(f"{'='*80}")
summary_df = pd.DataFrame(results_summary)
print(summary_df.to_string(index=False))
# Out:
# C:\Users\asusv\AppData\Local\Temp\ipykernel_10928\1290650992.py:12: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')
# ============================================================
# 1. DATASET
# ============================================================
# Dataset Books:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
# Info Dataset Books: 271360 rows, 8 columns
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB
# None
#
# Dataset Ratings:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
# Info Dataset Ratings: 1149780 rows, 3 columns
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB
# None
#
# Dataset Users:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN
# Info Dataset Users: 278858 rows, 3 columns
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB
# None
#
# ============================================================
# 2. PREPROCESSING DATA
# ============================================================
#
# Data setelah digabung: 1031136 rows, 12 columns
#
# --------------------------------------------------
# 2.1 CEK MISSING VALUE DAN HAPUS MISSING VALUE
# --------------------------------------------------
#
# Missing values sebelum preprocessing:
#              Missing Count  Percentage (%)
# Book-Author              2            0.00
# Publisher                2            0.00
# Image-URL-L              4            0.00
# Age                 277835           26.94
#
# Mengisi missing value Age dengan rata-rata: 37.40
# Menghapus baris dengan missing value pada kolom lainnya...
# Data berkurang dari 1031136 menjadi 1031128 rows (8 rows dihapus)
#
# Missing values setelah preprocessing:
# 0 missing values tersisa
#
# --------------------------------------------------
# 2.2 CEK OUTLIER DAN HAPUS OUTLIER
# --------------------------------------------------
#
# Analisis outlier untuk kolom Age:
# Q1: 31.0, Q3: 41.0, IQR: 10.0
# Batas bawah: 16.00, Batas atas: 56.00
# Jumlah outlier Age: 71910 (6.97%)
#
# Analisis outlier untuk kolom Book-Rating:
# count    1.031128e+06
# mean     2.839032e+00
# std      3.854147e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      7.000000e+00
# max      1.000000e+01
# Name: Book-Rating, dtype: float64
# Range valid rating: 0 - 10
#
# Menghapus outlier Age (< 5 atau > 100 tahun)...
# Data berkurang dari 1031128 menjadi 1026494 rows (4634 rows dihapus)
#
# Menghapus rating tidak valid (di luar range 0-10)...
# Data berkurang dari 1026494 menjadi 1026494 rows (0 rows dihapus)
#
# --------------------------------------------------
# 2.3 NORMALISASI
# --------------------------------------------------
# Melakukan encoding untuk User-ID dan ISBN...
# Total unique users: 91719
# Total unique books: 269491
#
# Normalisasi Book-Rating menggunakan MinMaxScaler...
# Rating sebelum normalisasi - Min: 0, Max: 10
# Rating setelah normalisasi - Min: 0.000, Max: 1.000
#
# Normalisasi Age menggunakan MinMaxScaler...
# Age sebelum normalisasi - Min: 5.00, Max: 100.00
# Age setelah normalisasi - Min: 0.000, Max: 1.000
#
# --------------------------------------------------
# RINGKASAN PREPROCESSING
# --------------------------------------------------
# Dataset final: 1026494 rows, 15 columns
# Unique users: 91719
# Unique books: 269491
# Rating range: 0.000 - 1.000
# Age range: 5.00 - 100.00 tahun
# Missing values: 0
#
# Sample data setelah preprocessing:
#    User-ID        ISBN           Book-Title           Book-Author  \
# 0        2  0195153448  Classical Mythology    Mark P. O. Morford
# 1        8  0002005018         Clara Callan  Richard Bruce Wright
# 2    11400  0002005018         Clara Callan  Richard Bruce Wright
# 3    11676  0002005018         Clara Callan  Richard Bruce Wright
# 4    41385  0002005018         Clara Callan  Richard Bruce Wright
#
#    Book-Rating        Age  user_idx  isbn_idx
# 0          0.0  18.000000         0         0
# 1          0.5  37.397648         1         1
# 2          0.0  49.000000         2         1
# 3          0.8  37.397648         3         1
# 4          0.0  37.397648         4         1
# ============================================================
# 3. SIMILARITY CALCULATION
# ============================================================
# Ukuran matriks sparse: (91719, 269491) (users x books)
# Sparsity: 100.00%
#
# Memfilter buku dengan minimal 10 rating...
# Buku populer: 17386 dari 269491 total buku
# Ukuran matriks setelah filtering: (91719, 17386)
#
# Menghitung Cosine Similarity...
# Cosine similarity matrix shape: (17386, 17386)
#
# Menghitung Euclidean Similarity...
# Euclidean similarity matrix shape: (17386, 17386)
#
# Menghitung Manhattan Similarity...
# Manhattan similarity matrix shape: (17386, 17386)
#
# Contoh Similarity Values (5x5 sample):
#
# Cosine Similarity:
#             0002005018  0374157065  0399135782  0440234743  0452264464
# 0002005018      1.0000         0.0      0.0900      0.0301      0.0382
# 0374157065      0.0000         1.0      0.0000      0.0000      0.0000
# 0399135782      0.0900         0.0      1.0000      0.0231      0.0292
# 0440234743      0.0301         0.0      0.0231      1.0000      0.0098
# 0452264464      0.0382         0.0      0.0292      0.0098      1.0000
#
# Euclidean Similarity:
#             0002005018  0374157065  0399135782  0440234743  0452264464
# 0002005018      1.0000      0.2473      0.2012      0.0874      0.1181
# 0374157065      0.2473      1.0000      0.2022      0.0875      0.1184
# 0399135782      0.2012      0.2022      1.0000      0.0853      0.1128
# 0440234743      0.0874      0.0875      0.0853      1.0000      0.0743
# 0452264464      0.1181      0.1184      0.1128      0.0743      1.0000
#
# Manhattan Similarity:
#             0002005018  0374157065  0399135782  0440234743  0452264464
# 0002005018      1.0000      0.0794      0.0495      0.0073      0.0148
# 0374157065      0.0794      1.0000      0.0510      0.0074      0.0149
# 0399135782      0.0495      0.0510      1.0000      0.0070      0.0134
# 0440234743      0.0073      0.0074      0.0070      1.0000      0.0052
# 0452264464      0.0148      0.0149      0.0134      0.0052      1.0000
#
# ============================================================
# 4. EVALUASI SISTEM REKOMENDASI
# ============================================================
# Mengevaluasi sistem untuk 20 user random...
#
# ================================================================================
# EVALUASI USER 1/20 - User-ID: 135082
# ================================================================================
# Buku yang pernah dibaca: 3 buku
#   1. Demon Diary, Book 3
#   2. Mars #1
#   3. Miracle Girls #1
#
# --- Cosine Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# ================================================================================
# EVALUASI USER 2/20 - User-ID: 98988
# ================================================================================
# Buku yang pernah dibaca: 33 buku
#   1. A Thousand Acres (Ballantine Reader's Circle)
#   2. White Oleander : A Novel
#   3. LAST TEMPTATION OF CHRIST (Movie Tie in)
#   4. Night
#   5. Catch Me If You Can: The True Story of a Real Fake
#   6. The Millionaire Next Door
#   7. The Law of Love
#   8. Gone for Good
#   9. The Nazi Officer's Wife : How One Jewish Woman Sur...
#   10. Tuesdays with Morrie: An Old Man, a Young Man, and...
#   11. Accident
#   12. When I Am an Old Woman I Shall Wear Purple
#   13. Ten Stupid Things Women Do to Mess Up Their Lives
#   14. Prince Charming Isn't Coming: How Women Get Smart ...
#   15. The Rules(TM) : Time-Tested Secrets for Capturing ...
#   16. How To Start A Conversation And Make Friends
#   17. The Beardstown Ladies' Guide to Smart Spending for...
#   18. Drawing on the Artist Within
#   19. Unnatural Death: Confessions of a Medical Examiner
#   20. Rules II: More Rules to Live and Love By
#   21. Daughters of the Elderly: Building Partnerships in...
#   22. Sailors to the End: The Deadly Fire on the Uss For...
#   23. Do It Yourself...or Not?
#   24. The Prince (Norton Critical Edition)
#   25. Hypnotism Made Practical
#   26. Why Women Pay More : How to Avoid Marketplace Peri...
#   27. Opening the Bible
#   28. Last Letter Home (The Emigrants Saga, No 4)
#   29. Unto a Good Land
#   30. How to Be Organized in Spite of Yourself: Time and...
#   31. Heaven Scent: Aromatic Gifts to Make, Send, and Ke...
#   32. Anger Kills
#   33. A Woman's Guide to a Simpler Life
#
# --- Cosine Similarity ---
# Rekomendasi: 42 buku
#   1. A Mind to Murder
#   2. Casey's Gamble  (Raising Cane)
#   3. Appetites: Why Women Want
#   4. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   5. She'S The Sheriff (Home On The Ranch) (Superromanc...
#   6. The Accidental Tourist : A Novel (Ballantine Reade...
#   7. The Age of Miracles
#   8. Henry and Ribsy 50th Anniversary Edition (Avon Cam...
#   9. Open Season
#   10. The Third Deadly Sin
#   11. The Last Kabbalist of Lisbon
#   12. The Church of Dead Girls
#   13. An Independent Woman
#   14. Blooming Murder (Iris House B &amp; B Mystery)
#   15. The Power of a Praying Wife
#   16. The Little Disturbances of Man (Contemporary Ameri...
#   17. Fade Away (Myron Bolitar Mysteries (Paperback))
#   18. Legwork (Casey Jones Mysteries)
#   19. The Beach Club : A Novel
#   20. Ticket Home
#   21. Duplicate Keys
#   22. Sons of Fortune (Ay Adult - Archer)
#   23. Flowers in the Rain
#   24. The Headless Cupid
#   25. One More Time
#   26. Pirates of the Caribbean: The Junior Novelization
#   27. The Cloister Walk
#   28. Walden Two (Trade Book)
#   29. How to Cook a Tart
#   30. Sideways Arithmetic from Wayside School
#   31. Macbeth
#   32. Guardian  (Guaranteed Page-Turner) (Harlequin Supe...
#   33. Smart Vs. Pretty
#   34. Chicken Soup for the Parent's Soul : 101 Stories o...
#   35. The Visitor
#   36. Helen Keller (Scholastic Biography)
#   37. Dream of Orchids
#   38. Trial by Fire
#   39. All Creatures Great and Small
#   40. Gossip Girl
#   41. The Ladies Auxiliary: A Novel
#   42. A Walk Across America
# Jumlah rekomendasi: 42 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 39 buku
#   1. A Mind to Murder
#   2. Casey's Gamble  (Raising Cane)
#   3. The First Man You Meet / Jacob's Girls
#   4. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   5. Thinking Out Loud: On the Personal, the Political,...
#   6. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   7. She'S The Sheriff (Home On The Ranch) (Superromanc...
#   8. The Age of Miracles
#   9. Quoth the Raven
#   10. Buddenbrooks. Verfall einer Familie.
#   11. Books and Reading: A Book of Quotations (Dover Thr...
#   12. The Last Valentine
#   13. Custard's Last Stand: A Pennsylvania Dutch Mystery...
#   14. Hawk O'Toole's Hostage
#   15. An Independent Woman
#   16. Starring Sally J. Freedman As Herself
#   17. Fade Away (Myron Bolitar Mysteries (Paperback))
#   18. Legwork (Casey Jones Mysteries)
#   19. The Beach Club : A Novel
#   20. Die SÃ?Â¤ulen der Erde.
#   21. The Headless Cupid
#   22. One More Time
#   23. Anastasia on Her Own
#   24. Pu der BÃ?Â¤r.
#   25. The Reunion (Animorphs, 30)
#   26. Unholy Fire
#   27. Heart Of The Mat (Harlequin Romance, No 2876)
#   28. The Price : A Novel
#   29. Guardian  (Guaranteed Page-Turner) (Harlequin Supe...
#   30. Smart Vs. Pretty
#   31. Chicken Soup for the Parent's Soul : 101 Stories o...
#   32. The Visitor
#   33. Helen Keller (Scholastic Biography)
#   34. Dream of Orchids
#   35. The Ladies Auxiliary: A Novel
#   36. Gossip Girl
#   37. Portrait of the Artist As a Young Man (Wordsworth ...
#   38. Malibu
#   39. The Temple of My Familiar
# Jumlah rekomendasi: 39 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 36 buku
#   1. A Mind to Murder
#   2. Casey's Gamble  (Raising Cane)
#   3. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   4. Irresistible Impulse
#   5. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   6. She'S The Sheriff (Home On The Ranch) (Superromanc...
#   7. Predators
#   8. The Age of Miracles
#   9. 36 Hours Christmas (Silhouette Promo)
#   10. Tempting A Texan
#   11. Books and Reading: A Book of Quotations (Dover Thr...
#   12. Justice for Some
#   13. An Independent Woman
#   14. Consuming Passions: A Food-Obsessed Life
#   15. Das Auge des TÃ?Â¤nzers.
#   16. Legwork (Casey Jones Mysteries)
#   17. The Beach Club : A Novel
#   18. Hotel
#   19. Family Outing
#   20. Murder on the Qe2: A Murder, She Wrote Mystery : A...
#   21. The Headless Cupid
#   22. One More Time
#   23. Anastasia on Her Own
#   24. Scarlatti Inheritance
#   25. Pu der BÃ?Â¤r.
#   26. The Reunion (Animorphs, 30)
#   27. PRINCIPLE CENTERED LEADERSHIP
#   28. Heart Of The Mat (Harlequin Romance, No 2876)
#   29. Cat in a Crimson Haze : A Midnight Louie Mystery (...
#   30. False Witness
#   31. The Price : A Novel
#   32. Guardian  (Guaranteed Page-Turner) (Harlequin Supe...
#   33. Helen Keller (Scholastic Biography)
#   34. Dream of Orchids
#   35. The Ladies Auxiliary: A Novel
#   36. The Temple of My Familiar
# Jumlah rekomendasi: 36 buku
#
# ================================================================================
# EVALUASI USER 3/20 - User-ID: 53604
# ================================================================================
# Buku yang pernah dibaca: 5 buku
#   1. Timeline
#   2. Cry, the Beloved Country (Oprah's Book Club)
#   3. East of Eden (Oprah's Book Club)
#   4. The Dreaming Tree: The Dreamstone, the Tree of Swo...
#   5. The Ghost Sister
#
# --- Cosine Similarity ---
# Rekomendasi: 12 buku
#   1. Line of Fire (Corps (Paperback))
#   2. Sea of Silver Light (Otherland, Book 4)
#   3. Spring Moon: A Novel of China
#   4. Mama
#   5. The Last Heroes (Men at War (Paperback Jove))
#   6. Rogue Planet (Star Wars)
#   7. The Restaurant at the End of the Universe
#   8. Mr Phillips
#   9. The Bingo Palace
#   10. Not Between Brothers
#   11. Plain Language: A Novel
#   12. Heart Of The Mat (Harlequin Romance, No 2876)
# Jumlah rekomendasi: 12 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 12 buku
#   1. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   2. O Little Town Of Glory  (Men Of Glory) (Harlequin ...
#   3. Spring Moon: A Novel of China
#   4. Mama
#   5. The Last Heroes (Men at War (Paperback Jove))
#   6. The Pearl and The Red Pony (Two Books in One)
#   7. Mr Phillips
#   8. The Bingo Palace
#   9. Not Between Brothers
#   10. The Reunion (Animorphs, 30)
#   11. Plain Language: A Novel
#   12. The Magic Bullet
# Jumlah rekomendasi: 12 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 12 buku
#   1. Prisoner of Desire
#   2. Cosi fan tutte. Eine Geschichte.
#   3. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   4. The Last Heroes (Men at War (Paperback Jove))
#   5. The Chase
#   6. The Price : A Novel
#   7. The Bingo Palace
#   8. Karen's Cartwheel (Baby-Sitters Little Sister, 29)
#   9. Tempting A Texan
#   10. Memories of Megan  (Nighthawk Island)
#   11. Books and Reading: A Book of Quotations (Dover Thr...
#   12. The Magic Bullet
# Jumlah rekomendasi: 12 buku
#
# ================================================================================
# EVALUASI USER 4/20 - User-ID: 184787
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. Zen and the Art of Motorcycle Maintenance: An Inqu...
#
# --- Cosine Similarity ---
# Rekomendasi: 3 buku
#   1. Timequake
#   2. Zen Mind, Beginner's Mind
#   3. Confession
# Jumlah rekomendasi: 3 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 3 buku
#   1. The Burning Point
#   2. The Emerald Swan
#   3. Disguised Blessing
# Jumlah rekomendasi: 3 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 3 buku
#   1. The Burning Point
#   2. Disguised Blessing
#   3. Daniel'S Bride
# Jumlah rekomendasi: 3 buku
#
# ================================================================================
# EVALUASI USER 5/20 - User-ID: 6153
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. A Child Called \It\": One Child's Courage to Survi...
#
# --- Cosine Similarity ---
# Rekomendasi: 3 buku
#   1. A Man Named Dave: A Story of Triumph and Forgivene...
#   2. The Lost Boy: A Foster Child's Search for the Love...
#   3. Dreamscapes: Dark Moon
# Jumlah rekomendasi: 3 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 3 buku
#   1. Shameless
#   2. Fast Courting
#   3. Dreamscapes: Dark Moon
# Jumlah rekomendasi: 3 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 3 buku
#   1. Izzy, Willy-Nilly
#   2. Fast Courting
#   3. Dreamscapes: Dark Moon
# Jumlah rekomendasi: 3 buku
#
# ================================================================================
# EVALUASI USER 6/20 - User-ID: 205028
# ================================================================================
# Buku yang pernah dibaca: 2 buku
#   1. The Westing Game (Now in Speak!)
#   2. A Wrinkle In Time
#
# --- Cosine Similarity ---
# Rekomendasi: 5 buku
#   1. A Wind in the Door
#   2. Thinking Out Loud: On the Personal, the Political,...
#   3. Guardian  (Guaranteed Page-Turner) (Harlequin Supe...
#   4. Many Waters
#   5. The DIETER
# Jumlah rekomendasi: 5 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 6 buku
#   1. A Little Princess (Book and Charm)
#   2. Dave Barry Is Not Making This Up
#   3. Thinking Out Loud: On the Personal, the Political,...
#   4. She'S The Sheriff (Home On The Ranch) (Superromanc...
#   5. Dream of Orchids
#   6. Cat on the Edge : A Joe Grey Mystery
# Jumlah rekomendasi: 6 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 6 buku
#   1. A Little Princess (Book and Charm)
#   2. Dave Barry Is Not Making This Up
#   3. Thinking Out Loud: On the Personal, the Political,...
#   4. She'S The Sheriff (Home On The Ranch) (Superromanc...
#   5. Dream of Orchids
#   6. Sisth Grade Can Really Kill You
# Jumlah rekomendasi: 6 buku
#
# ================================================================================
# EVALUASI USER 7/20 - User-ID: 189747
# ================================================================================
# Buku yang pernah dibaca: 15 buku
#   1. A Time to Kill
#   2. The Lost World
#   3. The King of Torts
#   4. The Cardinal of the Kremlin (Jack Ryan Novels)
#   5. The Summons
#   6. The Hunt for Red October
#   7. Gravity : A Novel of Medical Suspense
#   8. Black Sunday
#   9. The Scorpio Illusion
#   10. Myst: The Book of Ti'ana
#   11. The Unforgiven
#   12. Killing Time
#   13. Quiller Bamboo
#   14. Shadow Moon (Chronicles of the Shadow War, Book 1)
#   15. Pacific Nightmare: How Japan Starts World War III ...
#
# --- Cosine Similarity ---
# Rekomendasi: 35 buku
#   1. The Simeon Chamber
#   2. Irresistible Impulse
#   3. The Chancellor Manuscript
#   4. America on Six Rubles a Day  or  How to Become a C...
#   5. Shadow Dawn (Chronicles of the Shadow War, Book 2)
#   6. The Man Who Could Not Shudder
#   7. Trauma
#   8. Bingo
#   9. Without Remorse
#   10. Island
#   11. Sense and Sensibility (Bantam Classics)
#   12. Myst, The: Book of Atrus
#   13. The Client
#   14. Sins of the Fathers
#   15. Night Gardening
#   16. The moment of the magician
#   17. Jurassic Park
#   18. Krondor the Assassins (The Riftwar Legacy, Book 2)
#   19. The Last Heroes (Men at War (Paperback Jove))
#   20. The THRILL CLUB (FEAR STREET ) : THE THRILL CLUB
#   21. GIFT OF MAGIC : GIFT OF MAGIC
#   22. Patriot Games (Jack Ryan Novels)
#   23. Establishment
#   24. The Snowman
#   25. Myst, The: Book of D'Ni
#   26. HIS LITTLE WOMEN : HIS LITTLE WOMEN
#   27. The Firm
#   28. The Fighting Agents (Men at War (Paperback Jove))
#   29. Red Storm Rising
#   30. Sweet Death Kind Death (Kate Fansler Novels (Paper...
#   31. Loose Lips
#   32. SHINY WATER
#   33. Rogue
#   34. The Pelican Brief
#   35. China Sea (A Dan Lenson Novel)
# Jumlah rekomendasi: 35 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 32 buku
#   1. Panama: A Novel
#   2. Irresistible Impulse
#   3. Good Morning, Irene (Irene Adler)
#   4. The Chancellor Manuscript
#   5. Quoth the Raven
#   6. The Black Knight
#   7. Q Clearance
#   8. America on Six Rubles a Day  or  How to Become a C...
#   9. Shadow Dawn (Chronicles of the Shadow War, Book 2)
#   10. Two Much Alike (Twins) (Harlequin Superromance, No...
#   11. Foreign Affair (Harlequin Romance, No 3283)
#   12. The Man Who Could Not Shudder
#   13. Island
#   14. Close Combat (Corps (Paperback))
#   15. Silver Scream : A Bed-and-Breakfast Mystery (Bed-A...
#   16. Sins of the Fathers
#   17. Night Gardening
#   18. The moment of the magician
#   19. Krondor the Assassins (The Riftwar Legacy, Book 2)
#   20. The THRILL CLUB (FEAR STREET ) : THE THRILL CLUB
#   21. The Snowman
#   22. Myst, The: Book of D'Ni
#   23. The Fighting Agents (Men at War (Paperback Jove))
#   24. Cooks Overboard (Angie Amalfi Mysteries)
#   25. Sweet Death Kind Death (Kate Fansler Novels (Paper...
#   26. Sideways Arithmetic from Wayside School
#   27. Loose Lips
#   28. Prey (Aliens Vs. Predator, Book 1)
#   29. SHINY WATER
#   30. Rogue
#   31. Alburquerque
#   32. Malibu
# Jumlah rekomendasi: 32 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 33 buku
#   1. SS/GB
#   2. Panama: A Novel
#   3. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   4. Irresistible Impulse
#   5. Good Morning, Irene (Irene Adler)
#   6. The Hope : A Novel
#   7. The Chancellor Manuscript
#   8. The Black Knight
#   9. America on Six Rubles a Day  or  How to Become a C...
#   10. Shadow Dawn (Chronicles of the Shadow War, Book 2)
#   11. Two Much Alike (Twins) (Harlequin Superromance, No...
#   12. Foreign Affair (Harlequin Romance, No 3283)
#   13. The Man Who Could Not Shudder
#   14. Island
#   15. Close Combat (Corps (Paperback))
#   16. Sins of the Fathers
#   17. Night Gardening
#   18. The moment of the magician
#   19. The Last Heroes (Men at War (Paperback Jove))
#   20. The THRILL CLUB (FEAR STREET ) : THE THRILL CLUB
#   21. Acts of Love
#   22. The Snowman
#   23. Myst, The: Book of D'Ni
#   24. The Fighting Agents (Men at War (Paperback Jove))
#   25. Cooks Overboard (Angie Amalfi Mysteries)
#   26. Sweet Death Kind Death (Kate Fansler Novels (Paper...
#   27. Sideways Arithmetic from Wayside School
#   28. The Trouble With Lemons
#   29. SHINY WATER
#   30. Prey (Aliens Vs. Predator, Book 1)
#   31. Rogue
#   32. Alburquerque
#   33. Jingle Bells, Wedding Bells
# Jumlah rekomendasi: 33 buku
#
# ================================================================================
# EVALUASI USER 8/20 - User-ID: 161662
# ================================================================================
# Buku yang pernah dibaca: 27 buku
#   1. Househusband
#   2. The No. 1 Ladies' Detective Agency (Today Show Boo...
#   3. Faking It
#   4. How to Be Good
#   5. Feast of All Saints
#   6. Range of Motion
#   7. The Devil Wears Prada : A Novel
#   8. ESAU
#   9. Open House
#   10. The Bachelor (Warner Books Contemporary Romance)
#   11. Three Fates
#   12. Blood and Gold (Rice, Anne, Vampire Chronicles.)
#   13. Midnight Bayou
#   14. Fantasy Lover
#   15. Key of Knowledge (Key Trilogy (Paperback))
#   16. Key of Valor (Roberts, Nora. Key Trilogy, 3.)
#   17. Key of Light (Key Trilogy (Paperback))
#   18. Dating Without Novocaine (Red Dress Ink)
#   19. Joy School
#   20. Angels
#   21. Irish Born
#   22. The Heartbreaker
#   23. Slim Chance (Red Dress Ink (Paperback))
#   24. Bookends
#   25. Love By Design
#   26. Durable Goods
#   27. The Zygote Chronicles: A Novel
#
# --- Cosine Similarity ---
# Rekomendasi: 67 buku
#   1. Opposites Attract (Avon Romance)
#   2. Dance With The Devil: A Dark-Hunter Novel
#   3. Good Hope Road
#   4. Awaken, My Love (Brava Historical Romance)
#   5. A Clean Slate (Red Dress Ink)
#   6. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   7. Midnight Champagne: A Novel
#   8. Dog Handling
#   9. Tell Me Lies (Tell Me Lies)
#   10. The Carousel
#   11. 36 Hours Christmas (Silhouette Promo)
#   12. True to Form : A Novel
#   13. Under the Boardwalk
#   14. Open Season
#   15. True to Form : A Novel
#   16. King's Sacrifice (Star of the Guardians, Vol 3)
#   17. The Tale of the Body Thief (Vampire Chronicles (Pa...
#   18. Anastasia: The Last Grand Duchess, Russia, 1914 (T...
#   19. Crown Jewel : A Novel
#   20. The Sands of Time
#   21. Diceys Song
#   22. Moving Target
#   23. Cosi fan tutte. Eine Geschichte.
#   24. Mars and Venus on a Date : A Guide to Navigating t...
#   25. Keeping Faith : A Novel
#   26. Sacred Sins
#   27. Belinda
#   28. Consuming Passions: A Food-Obsessed Life
#   29. Because You're Mine (Avon Historical Romance)
#   30. Tangled Up in Love (Avon Light Contemporary Romanc...
#   31. Tell Me No Secrets
#   32. Windmills of the Gods
#   33. Someday Soon
#   34. Midnight Clear (3 Novels in 1)
#   35. Fire Within (America'S Bravest) (Harlequin Superro...
#   36. More Than You Know
#   37. Morality for Beautiful Girls (No.1 Ladies Detectiv...
#   38. Tears of the Giraffe (No.1 Ladies Detective Agency...
#   39. The Man Who Folded Himself
#   40. Night Embrace (Dark-Hunter)
#   41. The Ring on Her Finger (Avon Romance)
#   42. With All My Heart (A Kenyon Family Novel)
#   43. Good in Bed
#   44. Dark Fire
#   45. Searching for Caleb
#   46. Mysterious
#   47. Not Between Brothers
#   48. Someone's Watching
#   49. Pulse Points
#   50. About a Boy
#   51. Secrets of a Perfect Night: Scandalous Lord Dere/ ...
#   52. When the Sacred Ginmill Closes (Matthew Scudder My...
#   53. Killjoy
#   54. Heart Of The Mat (Harlequin Romance, No 2876)
#   55. Remember When (Roberts, Nora)
#   56. Highlander Unbound
#   57. A Girl's Best Friend
#   58. Glamorous Powers
#   59. PS, I Love You
#   60. SHINY WATER
#   61. More Than You Know: A Novel
#   62. Untamed
#   63. If the Slipper Fits (Avon Romance)
#   64. Odd Girl Out: The Hidden Culture of Aggression in ...
#   65. Helen Keller (Scholastic Biography)
#   66. My Heart Stood Still
#   67. This Must Be Love
# Jumlah rekomendasi: 67 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 66 buku
#   1. Enchantment (Heartspell)
#   2. Good Hope Road
#   3. Awaken, My Love (Brava Historical Romance)
#   4. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   5. The First Man You Meet / Jacob's Girls
#   6. Life Sentences
#   7. Born to Love
#   8. A Clean Slate (Red Dress Ink)
#   9. Heart Of The Night (Harlequin Intrigue, No 442)
#   10. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   11. Thinking Out Loud: On the Personal, the Political,...
#   12. The Carousel
#   13. Buddenbrooks. Verfall einer Familie.
#   14. Frl. Ursula: Roman
#   15. King's Sacrifice (Star of the Guardians, Vol 3)
#   16. Anastasia: The Last Grand Duchess, Russia, 1914 (T...
#   17. Perfect Match (Avon Light Contemporary Romances)
#   18. Prisoner of Desire
#   19. Crown Jewel : A Novel
#   20. Diceys Song
#   21. Cosi fan tutte. Eine Geschichte.
#   22. Heartbreaker (Lone Star Country Club)
#   23. A Dark Champion (Avon Romantic Treasure)
#   24. Consuming Passions: A Food-Obsessed Life
#   25. Donahue My Own Story
#   26. Because You're Mine (Avon Historical Romance)
#   27. Where Is He Now? (Avon Romance)
#   28. Love a Dark Rider
#   29. Tangled Up in Love (Avon Light Contemporary Romanc...
#   30. Tell Me No Secrets
#   31. Staying Single (Harlequin Flipside, No. 1)
#   32. Someday Soon
#   33. Midnight Clear (3 Novels in 1)
#   34. The Secret of Nimh
#   35. Amy  (Sisters) (Harlequin Super Romances, No 734)
#   36. More Than You Know
#   37. The Man Who Folded Himself
#   38. The Magic Bullet
#   39. Sinful
#   40. The Ring on Her Finger (Avon Romance)
#   41. O Little Town Of Glory  (Men Of Glory) (Harlequin ...
#   42. With All My Heart (A Kenyon Family Novel)
#   43. IN THE LINE OF FIRE - LONE STAR COUNTRY CLUB (Silh...
#   44. Searching for Caleb
#   45. The Reunion (Animorphs, 30)
#   46. Blackfire (Star Trek, No 8)
#   47. Someone's Watching
#   48. Pulse Points
#   49. Divining Women
#   50. Partisans
#   51. Secrets of a Perfect Night: Scandalous Lord Dere/ ...
#   52. When the Sacred Ginmill Closes (Matthew Scudder My...
#   53. Killjoy
#   54. Highlander Unbound
#   55. Peter Benchley's Creature
#   56. Cooks Overboard (Angie Amalfi Mysteries)
#   57. Seasons of the Heart
#   58. The Trelayne Inheritance (Candleglow)
#   59. Broken Honor
#   60. Smart Vs. Pretty
#   61. If the Slipper Fits (Avon Romance)
#   62. Odd Girl Out: The Hidden Culture of Aggression in ...
#   63. Helen Keller (Scholastic Biography)
#   64. My Heart Stood Still
#   65. Desire
#   66. This Must Be Love
# Jumlah rekomendasi: 66 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 63 buku
#   1. Enchantment (Heartspell)
#   2. Panama: A Novel
#   3. Good Hope Road
#   4. Awaken, My Love (Brava Historical Romance)
#   5. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   6. Lord Harry (Topaz Historical Romances)
#   7. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   8. Thinking Out Loud: On the Personal, the Political,...
#   9. Wife for a Day (Avon Light Contemporary Romances)
#   10. The Carousel
#   11. Quoth the Raven
#   12. Buddenbrooks. Verfall einer Familie.
#   13. The Gemini Man
#   14. Death of an Addict (Hamish Macbeth Mysteries (Hard...
#   15. Leaving Cold Sassy: The Unfinished Sequel to Cold ...
#   16. King's Sacrifice (Star of the Guardians, Vol 3)
#   17. VEIL: SECRET WARS OF THE CIA : VEIL: SECRET WARS O...
#   18. Prisoner of Desire
#   19. Crown Jewel : A Novel
#   20. Dujonian's Hoard (Star Trek The Next Generation: T...
#   21. Cosi fan tutte. Eine Geschichte.
#   22. Victims
#   23. Paper Money
#   24. A Dark Champion (Avon Romantic Treasure)
#   25. The Best of Friends: Joanna Trollope
#   26. Donahue My Own Story
#   27. Simply Love
#   28. Because You're Mine (Avon Historical Romance)
#   29. Consuming Passions: A Food-Obsessed Life
#   30. Where Is He Now? (Avon Romance)
#   31. Love a Dark Rider
#   32. Tangled Up in Love (Avon Light Contemporary Romanc...
#   33. Someday Soon
#   34. Staying Single (Harlequin Flipside, No. 1)
#   35. Midnight Clear (3 Novels in 1)
#   36. The Secret of Nimh
#   37. Tempt Me Twice (A Kenyon Family Novel)
#   38. More Than You Know
#   39. The Man Who Folded Himself
#   40. The Magic Bullet
#   41. After Sundown
#   42. Lives of Girls and Women (Vintage Contemporaries)
#   43. With All My Heart (A Kenyon Family Novel)
#   44. Pu der BÃ?Â¤r.
#   45. Searching for Caleb
#   46. The Reunion (Animorphs, 30)
#   47. Pulse Points
#   48. Divining Women
#   49. The Bride Thief
#   50. Secrets of a Perfect Night: Scandalous Lord Dere/ ...
#   51. Killjoy
#   52. Highlander Unbound
#   53. Peter Benchley's Creature
#   54. Sweet Death Kind Death (Kate Fansler Novels (Paper...
#   55. Broken Honor
#   56. Smart Vs. Pretty
#   57. If the Slipper Fits (Avon Romance)
#   58. Odd Girl Out: The Hidden Culture of Aggression in ...
#   59. Helen Keller (Scholastic Biography)
#   60. Denim And Diamonds
#   61. My Heart Stood Still
#   62. Desire
#   63. This Must Be Love
# Jumlah rekomendasi: 63 buku
#
# ================================================================================
# EVALUASI USER 9/20 - User-ID: 176467
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. Living at the Edge of the World: How I Survived th...
#
# --- Cosine Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# ================================================================================
# EVALUASI USER 10/20 - User-ID: 83392
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. The Secret Garden
#
# --- Cosine Similarity ---
# Rekomendasi: 3 buku
#   1. Airport
#   2. The Chase
#   3. Risen
# Jumlah rekomendasi: 3 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 3 buku
#   1. Airport
#   2. The Price : A Novel
#   3. Risen
# Jumlah rekomendasi: 3 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 3 buku
#   1. Gossip Girl
#   2. Airport
#   3. The Beach Club : A Novel
# Jumlah rekomendasi: 3 buku
#
# ================================================================================
# EVALUASI USER 11/20 - User-ID: 164056
# ================================================================================
# Buku yang pernah dibaca: 5 buku
#   1. House of Stairs
#   2. The Walking
#   3. Both Sides of Time (Scholastic Classics)
#   4. The Secret of Dragonhome
#   5. You Remind Me of You: A Poetry Memoir (Push Poetry...
#
# --- Cosine Similarity ---
# Rekomendasi: 9 buku
#   1. Wolf by the Ears (Point)
#   2. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   3. The Restaurant at the End of the Universe
#   4. Out of Time
#   5. The Town
#   6. Talking to Dragons (Enchanted Forest Chronicles (P...
#   7. Burning Up
#   8. Crown Duel (Smith, Sherwood. Crown and Court Duet,...
#   9. Four Dark Nights
# Jumlah rekomendasi: 9 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 9 buku
#   1. O Little Town Of Glory  (Men Of Glory) (Harlequin ...
#   2. God Bless This Child
#   3. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   4. Out of Time
#   5. Pu der BÃ?Â¤r.
#   6. Burning Up
#   7. Kunst des Reisens.
#   8. Always and Forever
#   9. Malibu
# Jumlah rekomendasi: 9 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 8 buku
#   1. Panama: A Novel
#   2. Cooks Overboard (Angie Amalfi Mysteries)
#   3. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   4. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   5. Out of Time
#   6. The Reunion (Animorphs, 30)
#   7. Kunst des Reisens.
#   8. Die SÃ?Â¤ulen der Erde.
# Jumlah rekomendasi: 8 buku
#
# ================================================================================
# EVALUASI USER 12/20 - User-ID: 55320
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. Fred Hollows : an autobiography
#
# --- Cosine Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: Tidak ada (buku tidak ditemukan dalam similarity matrix)
# Jumlah rekomendasi: 0 buku
#
# ================================================================================
# EVALUASI USER 13/20 - User-ID: 104875
# ================================================================================
# Buku yang pernah dibaca: 4 buku
#   1. Chaos: Making a New Science
#   2. Cryptonomicon
#   3. Cosmic Trigger I : Final Secret of the Illuminati
#   4. Zen Training: Methods and Philosophy
#
# --- Cosine Similarity ---
# Rekomendasi: 6 buku
#   1. Humorous Stories and Sketches (Dover Thrift Editio...
#   2. The Progress of Love (King Penguin)
#   3. Cadillac Jukebox (Dave Robicheaux Mysteries (Hardc...
#   4. Ride a Pale Horse
#   5. Hunchback of Notre Dame
#   6. To the Lighthouse
# Jumlah rekomendasi: 6 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 6 buku
#   1. Hidden Target -4
#   2. Mutiny on the Enterprise (Star Trek, No 12)
#   3. O Little Town Of Glory  (Men Of Glory) (Harlequin ...
#   4. Humorous Stories and Sketches (Dover Thrift Editio...
#   5. Cadillac Jukebox (Dave Robicheaux Mysteries (Hardc...
#   6. To the Lighthouse
# Jumlah rekomendasi: 6 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 6 buku
#   1. Alice Springs
#   2. The Secret Sisters
#   3. Humorous Stories and Sketches (Dover Thrift Editio...
#   4. Bsc Mallory and Trouble (R (Baby-Sitters Club (Pap...
#   5. ONE SUMMER EVENING
#   6. To the Lighthouse
# Jumlah rekomendasi: 6 buku
#
# ================================================================================
# EVALUASI USER 14/20 - User-ID: 153927
# ================================================================================
# Buku yang pernah dibaca: 38 buku
#   1. From the Corner of His Eye
#   2. Reap the Wind
#   3. North Country Man
#   4. Sarah's Baby  (Koomera Crossing)
#   5. The Woman Next Door
#   6. A Bend in the Road
#   7. Heaven and Earth (Three Sisters Island Trilogy)
#   8. Time And Again
#   9. This Calder Range Volume 1
#   10. Soldiers Of Fortune
#   11. Soul Harvest: The World Takes Sides (Left Behind N...
#   12. Lone Eagle
#   13. The Indwelling: The Beast Takes Possession (Left B...
#   14. Sweet Revenge
#   15. Born In The Valley  (Shelter Valley Stories)
#   16. Vital Signs  (Emergency!)
#   17. Against the Odds  (Serenity House)
#   18. Wildes Of Wyoming--Chance (The Wildes Of Wyoming) ...
#   19. A Husband Of Her Own
#   20. For The Defense  (White Knight Investigations)
#   21. 101 Ways to Get Straight A's (101 Ways)
#   22. Only His
#   23. The Clown of God
#   24. UNEXPECTED OUTCOME (Harlequin Superromance, No. 10...
#   25. In His Steps Nelson's Royal Classics
#   26. Brides to Be (2 Novels in 1)
#   27. The Target  (The Guardians)
#   28. Father Factor (Women Who Dare) (Harlequin Superrom...
#   29. After That Night  (9 Months Later)
#   30. Negotiator (The Guardians) (Harlequin Super Romanc...
#   31. Jackson's Girls  (Raising Cane)
#   32. Sicilian'S Mistress (Amnesia/Xmas) (Presents, 2139...
#   33. Wrong Bride, Right Groom  (Holiday Honeymoons) (Ha...
#   34. 101 Ways to Do Better in School
#   35. Your Place In This World
#   36. 107 Questions Children Ask about Prayer (Questions...
#   37. Most Passionate Revenge (Presents Passion) (Presen...
#   38. Convenient Husband (Silhouette Desire, No 732)
#
# --- Cosine Similarity ---
# Rekomendasi: 57 buku
#   1. Flu: The Story of the Great Influenza Pandemic of ...
#   2. Apollyon: The Destroyer Is Unleashed (Left Behind ...
#   3. The Infinite (Leisure Horror)
#   4. Roomful Of Roses
#   5. Monday'S Child (Bestselling Author) (Harlequin Sup...
#   6. Face the Fire (Three Sisters Island Trilogy)
#   7. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   8. Assassins: Assignment: Jerusalem, Target: Antichri...
#   9. Condensed Chicken Soup for the Soul (Chicken Soup ...
#   10. Strange but True
#   11. Desecration: Antichrist Takes the Throne (Left Beh...
#   12. Skin Deep
#   13. Montana Dreaming  (Home On The Ranch) (Harlequin S...
#   14. Only You
#   15. Private Scandals
#   16. Upon a Wicked Time (An Avon Romantic Treasure)
#   17. Cupid'S Revenge (Camerons Of Colorado) (Superroman...
#   18. Under Lock And Key
#   19. Jewels of the Sun (Irish Trilogy)
#   20. Becoming a Woman of Excellence
#   21. Girlfriend 44
#   22. Paper Rose
#   23. Midnight Clear (3 Novels in 1)
#   24. Navy Blues
#   25. The Funhouse
#   26. Lord Of The Desert (Mira)
#   27. Tidewater
#   28. Tribulation Force: The Continuing Drama of Those L...
#   29. Sinful
#   30. Man With A Mission (The Men Of Maple Hill) (Harleq...
#   31. After the Parade
#   32. A Little Town In Texas  (Crystal Creek)
#   33. Nicolae: The Rise of Antichrist (Left Behind No. 3...
#   34. The Mark: The Beast Rules the World (Left Behind N...
#   35. Lady'S Choice
#   36. The Sweetest Christmas (Disney's Pooh)
#   37. The Homing
#   38. Dating Game
#   39. Beauty Queen (Berkley Sensation)
#   40. The SECRET BEDROOM (FEAR STREET ) : THE SECRET BED...
#   41. Contact
#   42. Lake News
#   43. Clara Callan
#   44. The Kitchen God's Wife
#   45. Trouble Becomes Her
#   46. The Farmer's Wife
#   47. God Bless This Child
#   48. Untamed
#   49. Necroscope 3: The Source (Necroscope Trilogy, Volu...
#   50. Winter Fire
#   51. Blue Moon
#   52. Home To Copper Mountain
#   53. Dance upon the Air (Three Sisters Island Trilogy)
#   54. Daniel'S Bride
#   55. Denim And Diamonds
#   56. Mrs. Pollifax Unveiled (Mrs. Pollifax Mysteries (P...
#   57. The Bride's Rescuer
# Jumlah rekomendasi: 57 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 55 buku
#   1. Father'S Heart  (Family Man) (Superromance , No 78...
#   2. Apollyon: The Destroyer Is Unleashed (Left Behind ...
#   3. The Infinite (Leisure Horror)
#   4. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   5. Roomful Of Roses
#   6. No Other Love
#   7. Monday'S Child (Bestselling Author) (Harlequin Sup...
#   8. The Gold Coin (Sonnet Books)
#   9. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   10. The Carousel
#   11. Assassins: Assignment: Jerusalem, Target: Antichri...
#   12. Desecration: Antichrist Takes the Throne (Left Beh...
#   13. Ghost-Walker (Star Trek, Book 53)
#   14. The Book on the Bookshelf
#   15. Once an Angel
#   16. Skin Deep
#   17. Sleeping Murder: Miss Marple's Last Case
#   18. Calling All Creeps! (Goosebumps, No 50)
#   19. Montana Dreaming  (Home On The Ranch) (Harlequin S...
#   20. Dark Enchantment
#   21. Cupid'S Revenge (Camerons Of Colorado) (Superroman...
#   22. Other Amanda  (Loving Dangerously) (Harlequin Supe...
#   23. Girlfriend 44
#   24. Paper Rose
#   25. Confession
#   26. Bsc Mallory and Trouble (R (Baby-Sitters Club (Pap...
#   27. Midnight Clear (3 Novels in 1)
#   28. Lord Of The Desert (Mira)
#   29. Never Say Die
#   30. Sinful
#   31. More Than You Know
#   32. Rancher'S Wife (Harlequin Historical, No. 470)
#   33. Whispers
#   34. After the Parade
#   35. O Little Town Of Glory  (Men Of Glory) (Harlequin ...
#   36. A Little Town In Texas  (Crystal Creek)
#   37. Too Deep for Tears
#   38. Thunder Creek
#   39. The Mark: The Beast Rules the World (Left Behind N...
#   40. The Sweetest Christmas (Disney's Pooh)
#   41. The Homing
#   42. Beauty Queen (Berkley Sensation)
#   43. Help! I'm a Prisoner in the Library
#   44. Kiss Mommy Goodbye
#   45. Trouble Becomes Her
#   46. Virtual Heaven (Perfect Heroes Series, 2)
#   47. The Emerald Swan
#   48. God Bless This Child
#   49. Necroscope 3: The Source (Necroscope Trilogy, Volu...
#   50. Jingle Bells, Wedding Bells
#   51. Winter Fire
#   52. Do You Want to Know a Secret?
#   53. Blue Moon
#   54. Denim And Diamonds
#   55. Bodyguard  (Elk River, Colorado) (Harlequin Intrig...
# Jumlah rekomendasi: 55 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 54 buku
#   1. Gulliver's Travels (Signet Classics (Paperback))
#   2. Father'S Heart  (Family Man) (Superromance , No 78...
#   3. Apollyon: The Destroyer Is Unleashed (Left Behind ...
#   4. Roomful Of Roses
#   5. Monday'S Child (Bestselling Author) (Harlequin Sup...
#   6. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   7. Assassins: Assignment: Jerusalem, Target: Antichri...
#   8. Buddenbrooks. Verfall einer Familie.
#   9. Who Killed Mr. Boddy? (Clue)
#   10. Desecration: Antichrist Takes the Throne (Left Beh...
#   11. Tempting A Texan
#   12. Ghost-Walker (Star Trek, Book 53)
#   13. Forever After
#   14. Skin Deep
#   15. Prisoner of Desire
#   16. Montana Dreaming  (Home On The Ranch) (Harlequin S...
#   17. Cosi fan tutte. Eine Geschichte.
#   18. Dark Enchantment
#   19. Cupid'S Revenge (Camerons Of Colorado) (Superroman...
#   20. Mistletoe Marriages
#   21. Girlfriend 44
#   22. Confession
#   23. Midnight Clear (3 Novels in 1)
#   24. A Spirited Seduction (Haunting Hearts)
#   25. Lord Of The Desert (Mira)
#   26. More Than You Know
#   27. Rancher'S Wife (Harlequin Historical, No. 470)
#   28. The Burning Point
#   29. After the Parade
#   30. A Little Town In Texas  (Crystal Creek)
#   31. Too Deep for Tears
#   32. Thunder Creek
#   33. The Mark: The Beast Rules the World (Left Behind N...
#   34. Pu der BÃ?Â¤r.
#   35. The Reunion (Animorphs, 30)
#   36. The Sweetest Christmas (Disney's Pooh)
#   37. A Love to Keep
#   38. Beauty Queen (Berkley Sensation)
#   39. Kiss Mommy Goodbye
#   40. Mccallum Quintuplets (Maitland Maternity: Triplets...
#   41. The Foot Book : Dr. Seuss's Wacky Book of Opposite...
#   42. Trouble Becomes Her
#   43. Virtual Heaven (Perfect Heroes Series, 2)
#   44. God Bless This Child
#   45. Rules of Command
#   46. Necroscope 3: The Source (Necroscope Trilogy, Volu...
#   47. Jingle Bells, Wedding Bells
#   48. Winter Fire
#   49. Blue Moon
#   50. The Chisellers
#   51. Denim And Diamonds
#   52. Daniel'S Bride
#   53. The Veiled One
#   54. Karens Prize (Baby-Sitters Little Sister, 11)
# Jumlah rekomendasi: 54 buku
#
# ================================================================================
# EVALUASI USER 15/20 - User-ID: 157103
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. Seabiscuit: An American Legend
#
# --- Cosine Similarity ---
# Rekomendasi: 3 buku
#   1. Right as Rain
#   2. Gai-Jin: A Novel of Japan
#   3. Not Between Brothers
# Jumlah rekomendasi: 3 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 3 buku
#   1. Right as Rain
#   2. Gai-Jin: A Novel of Japan
#   3. Not Between Brothers
# Jumlah rekomendasi: 3 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 3 buku
#   1. Right as Rain
#   2. Gai-Jin: A Novel of Japan
#   3. Not Between Brothers
# Jumlah rekomendasi: 3 buku
#
# ================================================================================
# EVALUASI USER 16/20 - User-ID: 273905
# ================================================================================
# Buku yang pernah dibaca: 7 buku
#   1. Hannibal
#   2. Hemlock Bay
#   3. The Night Before
#   4. Mortal Prey
#   5. Best Of James Beard
#   6. The New Good Housekeeping Cookbook
#   7. I Am Not Going to Get Up Today! (Beginner Books)
#
# --- Cosine Similarity ---
# Rekomendasi: 12 buku
#   1. Every Waking Moment
#   2. The Shoemaker :  The Anatomy of a Psychotic
#   3. Red Dragon
#   4. Golden Lasso
#   5. Sweet Death Kind Death (Kate Fansler Novels (Paper...
#   6. The Titanic: Lost and Found (Step-Into-Reading, St...
#   7. The Chase
#   8. Rogue
#   9. Godplayer
#   10. Until Proven Guilty
#   11. Necessary Evil
#   12. The Last Valentine
# Jumlah rekomendasi: 12 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 12 buku
#   1. Every Waking Moment
#   2. Grand Passion
#   3. The Shoemaker :  The Anatomy of a Psychotic
#   4. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   5. The Chase
#   6. Rogue
#   7. Until Proven Guilty
#   8. Necessary Evil
#   9. Dreamscapes: Dark Moon
#   10. The Last Valentine
#   11. The RUGRATS MOVIE (Rugrats)
#   12. Hawk O'Toole's Hostage
# Jumlah rekomendasi: 12 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 12 buku
#   1. Every Waking Moment
#   2. The Shoemaker :  The Anatomy of a Psychotic
#   3. Cooks Overboard (Angie Amalfi Mysteries)
#   4. Cosi fan tutte. Eine Geschichte.
#   5. Baby-Sitters Beware (Baby-Sitters Club Super Myste...
#   6. The Chase
#   7. The Price : A Novel
#   8. Until Proven Guilty
#   9. Denim And Diamonds
#   10. Dreamscapes: Dark Moon
#   11. Books and Reading: A Book of Quotations (Dover Thr...
#   12. The RUGRATS MOVIE (Rugrats)
# Jumlah rekomendasi: 12 buku
#
# ================================================================================
# EVALUASI USER 17/20 - User-ID: 155650
# ================================================================================
# Buku yang pernah dibaca: 17 buku
#   1. Mystic River
#   2. One Door Away from Heaven
#   3. The Bourne Supremacy
#   4. Time and Chance
#   5. Emma Who Saved My Life
#   6. Always Six O'Clock
#   7. Memoirs of an Invisible Man
#   8. Fair Ball: A Fan's Case for Baseball
#   9. The Twelfth Angel
#   10. Wild Pitch
#   11. The Book of Skulls
#   12. Drag Queen
#   13. Best Transgender Erotica
#   14. Hit Me With a Rainbow
#   15. The Way It Should Have Been
#   16. The Dugout Bible: Coaching Youth Baseball for Succ...
#   17. Baseball For Real Men
#
# --- Cosine Similarity ---
# Rekomendasi: 12 buku
#   1. Flint Hills Bride (Historical , No 430)
#   2. The Best Revenge
#   3. God Game
#   4. Wit and Wisdom of Mark Twain: A Book of Quotations...
#   5. Spycatcher
#   6. Violation
#   7. God Bless This Child
#   8. Angel of Death
#   9. Happy Endings
#   10. Undone
#   11. Fletch, Too
#   12. The Bourne Ultimatum
# Jumlah rekomendasi: 12 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 12 buku
#   1. Flint Hills Bride (Historical , No 430)
#   2. The Best Revenge
#   3. The Shoemaker :  The Anatomy of a Psychotic
#   4. God Game
#   5. Giants in the Earth: A Saga of the Prairie
#   6. Wit and Wisdom of Mark Twain: A Book of Quotations...
#   7. God Bless This Child
#   8. Angel of Death
#   9. Happy Endings
#   10. Angel Light: An Old-Fashioned Love Story
#   11. Fletch, Too
#   12. Fledgling
# Jumlah rekomendasi: 12 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 12 buku
#   1. Flint Hills Bride (Historical , No 430)
#   2. The Best Revenge
#   3. The Shoemaker :  The Anatomy of a Psychotic
#   4. Giants in the Earth: A Saga of the Prairie
#   5. Der Spaziergang. ProsastÃ?Â¼cke und kleine Prosa.
#   6. Wit and Wisdom of Mark Twain: A Book of Quotations...
#   7. Trouble Becomes Her
#   8. God Bless This Child
#   9. Happy Endings
#   10. Until Proven Guilty
#   11. Fletch, Too
#   12. Buddenbrooks. Verfall einer Familie.
# Jumlah rekomendasi: 12 buku
#
# ================================================================================
# EVALUASI USER 18/20 - User-ID: 172508
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. Homecoming
#
# --- Cosine Similarity ---
# Rekomendasi: 3 buku
#   1. Marco Polo, If You Can
#   2. The Ballad of Lucy Whipple
#   3. Annie's Rainbow (Zebra Contemporary Romance)
# Jumlah rekomendasi: 3 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 3 buku
#   1. Marco Polo, If You Can
#   2. The Ballad of Lucy Whipple
#   3. Annie's Rainbow (Zebra Contemporary Romance)
# Jumlah rekomendasi: 3 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 3 buku
#   1. Marco Polo, If You Can
#   2. The Ballad of Lucy Whipple
#   3. Annie's Rainbow (Zebra Contemporary Romance)
# Jumlah rekomendasi: 3 buku
#
# ================================================================================
# EVALUASI USER 19/20 - User-ID: 103425
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. The Luckiest Girl (An Avon Camelot Book)
#
# --- Cosine Similarity ---
# Rekomendasi: 3 buku
#   1. Harriet the Spy
#   2. Coming Home (Heartland)
#   3. Just Ella
# Jumlah rekomendasi: 3 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 3 buku
#   1. The Millennium Girl
#   2. Malibu
#   3. The Power That Preserves (The Chronicles of Thomas...
# Jumlah rekomendasi: 3 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 3 buku
#   1. The Reunion (Animorphs, 30)
#   2. Die SÃ?Â¤ulen der Erde.
#   3. Kunst des Reisens.
# Jumlah rekomendasi: 3 buku
#
# ================================================================================
# EVALUASI USER 20/20 - User-ID: 102810
# ================================================================================
# Buku yang pernah dibaca: 1 buku
#   1. ALL MY PATIENTS ARE UNDER THE BED
#
# --- Cosine Similarity ---
# Rekomendasi: 3 buku
#   1. A Snowflake in My Hand
#   2. McNally's Risk
#   3. A Cat on Jingle Bell Rock: An Alice Nestleton Myst...
# Jumlah rekomendasi: 3 buku
#
# --- Euclidean Similarity ---
# Rekomendasi: 3 buku
#   1. The Alpine Advocate (Emma Lord Mysteries)
#   2. McNally's Risk
#   3. A Cat on Jingle Bell Rock: An Alice Nestleton Myst...
# Jumlah rekomendasi: 3 buku
#
# --- Manhattan Similarity ---
# Rekomendasi: 3 buku
#   1. A Snowflake in My Hand
#   2. McNally's Risk
#   3. A Cat on Jingle Bell Rock: An Alice Nestleton Myst...
# Jumlah rekomendasi: 3 buku
#
# ================================================================================
# RINGKASAN EVALUASI AKHIR
# ================================================================================
# Cosine Similarity    : 17/20 user (85.0%) berhasil mendapat rekomendasi
#                        Rata-rata 13.9 rekomendasi per user
# Euclidean Similarity : 17/20 user (85.0%) berhasil mendapat rekomendasi
#                        Rata-rata 13.5 rekomendasi per user
# Manhattan Similarity : 17/20 user (85.0%) berhasil mendapat rekomendasi
#                        Rata-rata 13.2 rekomendasi per user
#
# 🏆 Metrik terbaik: Cosine Similarity
#    Berhasil memberikan rekomendasi untuk 17/20 user
#
# ================================================================================
# TABEL PERBANDINGAN METRIK
# ================================================================================
#               Method  Success Rate Avg Recommendations
#    Cosine Similarity 17/20 (85.0%)      13.9 buku/user
# Euclidean Similarity 17/20 (85.0%)      13.5 buku/user
# Manhattan Similarity 17/20 (85.0%)      13.2 buku/user
